# %%
from app.splitter import pdf_to_chunks
from langchain_community.vectorstores import Chroma
from app.models import embedding_model
from app.models import pipe, prompt_template
class pdf():
    def __init__(self, path):
        self.path = path

file = pdf("bitcoin_es.pdf")

chunks = pdf_to_chunks(file)
vector_db = Chroma.from_documents(documents=chunks, embedding=embedding_model)
# Out:
# c:\Users\tzbk\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py:4225: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(

# %%
queries = ["Como funciona bitcoin?", "Que es proof-of-work?", "Como se verifican los pagos?", "Cuales son los incentivos?"]
answers = []
for query in queries:
    results = vector_db.similarity_search(query)
    context = f"{results[0].page_content} {results[1].page_content}"

    prompt = prompt_template.format(context=context, prompt=query)
    respuesta = pipe(prompt)
    answers.append(respuesta)
# Out:
# c:\Users\tzbk\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\generation\configuration_utils.py:492: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.1` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# c:\Users\tzbk\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\generation\configuration_utils.py:497: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# c:\Users\tzbk\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\generation\configuration_utils.py:509: UserWarning: `do_sample` is set to `False`. However, `top_k` is set to `10` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_k`.
#   warnings.warn(
# c:\Users\tzbk\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\mistral\modeling_mistral.py:688: UserWarning: 1Torch was not compiled with flash attention. (Triggered internally at ..\aten\src\ATen\native\transformers\cuda\sdp_utils.cpp:263.)
#   attn_output = torch.nn.functional.scaled_dot_product_attention(

# %%
import pandas as pd

df = pd.DataFrame({"query": queries, "answer": answers})
df.to_csv("model_evaluation.csv", index=False)
